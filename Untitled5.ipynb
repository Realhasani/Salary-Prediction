# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px

import plotly.io as pio
pio.renderers.default = "notebook"

from sklearn.preprocessing import StandardScaler,LabelEncoder,MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
import warnings
warnings. filterwarnings('ignore')

# %%
df = pd.read_csv("/content/survey_results_public.csv")

columns_to_keep = [
    'EdLevel', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize',
    'Country', 'CompFreq', 'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith',
    'PlatformHaveWorkedWith', 'WebframeHaveWorkedWith', 'MiscTechHaveWorkedWith',
    'ToolsTechHaveWorkedWith', 'OpSysProfessional use', 'Age', 'Gender',
    'WorkExp', 'ICorPM', 'ConvertedCompYearly'
]

df = df[columns_to_keep]
df = df.dropna(subset=['ConvertedCompYearly'])

df['YearsCode'] = df['YearsCode'].replace({
    'Less than 1 year': '0.5',
    'More than 50 years': '50'
})
df['YearsCodePro'] = df['YearsCodePro'].replace({
    'Less than 1 year': '0.5',
    'More than 50 years': '50'
})

df['YearsCode'] = pd.to_numeric(df['YearsCode'], errors='coerce')
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')

df['YearsCode'] = df['YearsCode'].fillna(df['YearsCode'].median())
df['YearsCodePro'] = df['YearsCodePro'].fillna(df['YearsCodePro'].median())

label_encoder = LabelEncoder()

df['EdLevel'] = label_encoder.fit_transform(df['EdLevel'].fillna('Other'))
df['DevType'] = df['DevType'].fillna('Other').apply(lambda x: x.split(';')[0])
df['DevType'] = label_encoder.fit_transform(df['DevType'])
df['Country'] = label_encoder.fit_transform(df['Country'].fillna('Other'))
df['CompFreq'] = df['CompFreq'].map({'Yearly': 1, 'Monthly': 12, 'Weekly': 52}).fillna(1)

languages = df['LanguageHaveWorkedWith'].str.get_dummies(';')
df = pd.concat([df, languages], axis=1)

scaler = MinMaxScaler()
df[['YearsCode', 'YearsCodePro', 'ConvertedCompYearly']] = scaler.fit_transform(df[['YearsCode', 'YearsCodePro', 'ConvertedCompYearly']])
df = df.dropna()

# %%
from scipy import stats

z_scores = stats.zscore(df['ConvertedCompYearly'])
abs_z_scores = np.abs(z_scores)

threshold = 3
outliers_z = df[abs_z_scores > threshold]

df = df[abs_z_scores <= threshold]

# %%
pip install pycaret

# %%
from pycaret.regression import *
exp = setup(data=df, target='ConvertedCompYearly', session_id=123)
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ea44c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ea44c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea44c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ea44c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea44c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea44c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ea44c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea44c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ea44c_row1_col1" class="data row1 col1" >ConvertedCompYearly</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea44c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ea44c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ea44c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ea44c_row3_col1" class="data row3 col1" >(1459, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ea44c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ea44c_row4_col1" class="data row4 col1" >(1459, 103)</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ea44c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ea44c_row5_col1" class="data row5 col1" >(1021, 103)</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ea44c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ea44c_row6_col1" class="data row6 col1" >(438, 103)</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ea44c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ea44c_row7_col1" class="data row7 col1" >49</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ea44c_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_ea44c_row8_col1" class="data row8 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ea44c_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_ea44c_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ea44c_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_ea44c_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ea44c_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_ea44c_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ea44c_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_ea44c_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ea44c_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_ea44c_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ea44c_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_ea44c_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ea44c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_ea44c_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ea44c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_ea44c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ea44c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_ea44c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ea44c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_ea44c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ea44c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_ea44c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ea44c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_ea44c_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ea44c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ea44c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_ea44c_row21_col1" class="data row21 col1" >83d7</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_fad54 th {
#   text-align: left;
# }
# #T_fad54_row0_col0, #T_fad54_row0_col1, #T_fad54_row0_col6, #T_fad54_row1_col0, #T_fad54_row1_col3, #T_fad54_row1_col4, #T_fad54_row1_col5, #T_fad54_row1_col6, #T_fad54_row2_col0, #T_fad54_row2_col1, #T_fad54_row2_col3, #T_fad54_row2_col4, #T_fad54_row2_col5, #T_fad54_row2_col6, #T_fad54_row3_col0, #T_fad54_row3_col1, #T_fad54_row3_col3, #T_fad54_row3_col4, #T_fad54_row3_col5, #T_fad54_row3_col6, #T_fad54_row4_col0, #T_fad54_row4_col1, #T_fad54_row4_col3, #T_fad54_row4_col4, #T_fad54_row4_col5, #T_fad54_row4_col6, #T_fad54_row5_col0, #T_fad54_row5_col1, #T_fad54_row5_col3, #T_fad54_row5_col4, #T_fad54_row5_col5, #T_fad54_row5_col6, #T_fad54_row6_col0, #T_fad54_row6_col1, #T_fad54_row6_col3, #T_fad54_row6_col4, #T_fad54_row6_col5, #T_fad54_row6_col6, #T_fad54_row7_col0, #T_fad54_row7_col1, #T_fad54_row7_col3, #T_fad54_row7_col4, #T_fad54_row7_col5, #T_fad54_row7_col6, #T_fad54_row8_col0, #T_fad54_row8_col1, #T_fad54_row8_col3, #T_fad54_row8_col4, #T_fad54_row8_col5, #T_fad54_row8_col6, #T_fad54_row9_col0, #T_fad54_row9_col1, #T_fad54_row9_col3, #T_fad54_row9_col4, #T_fad54_row9_col5, #T_fad54_row9_col6, #T_fad54_row10_col0, #T_fad54_row10_col1, #T_fad54_row10_col3, #T_fad54_row10_col4, #T_fad54_row10_col5, #T_fad54_row10_col6, #T_fad54_row11_col0, #T_fad54_row11_col1, #T_fad54_row11_col3, #T_fad54_row11_col4, #T_fad54_row11_col5, #T_fad54_row11_col6, #T_fad54_row12_col0, #T_fad54_row12_col1, #T_fad54_row12_col3, #T_fad54_row12_col4, #T_fad54_row12_col5, #T_fad54_row12_col6, #T_fad54_row13_col0, #T_fad54_row13_col1, #T_fad54_row13_col3, #T_fad54_row13_col4, #T_fad54_row13_col5, #T_fad54_row13_col6, #T_fad54_row14_col0, #T_fad54_row14_col1, #T_fad54_row14_col3, #T_fad54_row14_col4, #T_fad54_row14_col5, #T_fad54_row14_col6, #T_fad54_row15_col0, #T_fad54_row15_col1, #T_fad54_row15_col3, #T_fad54_row15_col4, #T_fad54_row15_col5, #T_fad54_row15_col6, #T_fad54_row16_col0, #T_fad54_row16_col1, #T_fad54_row16_col3, #T_fad54_row16_col4, #T_fad54_row16_col5, #T_fad54_row16_col6, #T_fad54_row17_col0, #T_fad54_row17_col1, #T_fad54_row17_col3, #T_fad54_row17_col4, #T_fad54_row17_col5, #T_fad54_row18_col0, #T_fad54_row18_col1, #T_fad54_row18_col2, #T_fad54_row18_col3, #T_fad54_row18_col4, #T_fad54_row18_col5, #T_fad54_row18_col6 {
#   text-align: left;
# }
# #T_fad54_row0_col2, #T_fad54_row0_col3, #T_fad54_row0_col4, #T_fad54_row0_col5, #T_fad54_row1_col1, #T_fad54_row1_col2, #T_fad54_row2_col2, #T_fad54_row3_col2, #T_fad54_row4_col2, #T_fad54_row5_col2, #T_fad54_row6_col2, #T_fad54_row7_col2, #T_fad54_row8_col2, #T_fad54_row9_col2, #T_fad54_row10_col2, #T_fad54_row11_col2, #T_fad54_row12_col2, #T_fad54_row13_col2, #T_fad54_row14_col2, #T_fad54_row15_col2, #T_fad54_row16_col2, #T_fad54_row17_col2, #T_fad54_row17_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fad54_row0_col7, #T_fad54_row1_col7, #T_fad54_row2_col7, #T_fad54_row4_col7, #T_fad54_row5_col7, #T_fad54_row6_col7, #T_fad54_row7_col7, #T_fad54_row8_col7, #T_fad54_row9_col7, #T_fad54_row10_col7, #T_fad54_row11_col7, #T_fad54_row12_col7, #T_fad54_row13_col7, #T_fad54_row14_col7, #T_fad54_row15_col7, #T_fad54_row16_col7, #T_fad54_row17_col7, #T_fad54_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fad54_row3_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fad54" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fad54_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fad54_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fad54_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fad54_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fad54_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fad54_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fad54_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fad54_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fad54_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_fad54_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_fad54_row0_col1" class="data row0 col1" >0.0018</td>
#       <td id="T_fad54_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_fad54_row0_col3" class="data row0 col3" >0.0033</td>
#       <td id="T_fad54_row0_col4" class="data row0 col4" >0.0114</td>
#       <td id="T_fad54_row0_col5" class="data row0 col5" >0.0033</td>
#       <td id="T_fad54_row0_col6" class="data row0 col6" >27.7485</td>
#       <td id="T_fad54_row0_col7" class="data row0 col7" >0.2320</td>
#     </tr>
#     <tr>
#       <th id="T_fad54_level0_row1" class="row_heading level0 row1" >huber</th>
#       <td id="T_fad54_row1_col0" class="data row1 col0" >Huber Regressor</td>
#       <td id="T_fad54_row1_col1" class="data row1 col1" >0.0014</td>
#       <td id="T_fad54_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_fad54_row1_col3" class="data row1 col3" >0.0034</td>
#       <td id="T_fad54_row1_col4" class="data row1 col4" >0.0061</td>
#       <td id="T_fad54_row1_col5" class="data row1 col5" >0.0034</td>
#       <td id="T_fad54_row1_col6" class="data row1 col6" >16.0956</td>
#       <td id="T_fad54_row1_col7" class="data row1 col7" >0.5330</td>
#     </tr>
#     <tr>
#       <th id="T_fad54_level0_row2" class="row_heading level0 row2" >llar</th>
#       <td id="T_fad54_row2_col0" class="data row2 col0" >Lasso Least Angle Regression</td>
#       <td id="T_fad54_row2_col1" class="data row2 col1" >0.0018</td>
#       <td id="T_fad54_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_fad54_row2_col3" class="data row2 col3" >0.0034</td>
#       <td id="T_fad54_row2_col4" class="data row2 col4" >-0.0131</td>
#       <td id="T_fad54_row2_col5" class="data row2 col5" >0.0034</td>
#       <td id="T_fad54_row2_col6" class="data row2 col6" >28.9565</td>
#       <td id="T_fad54_row2_col7" class="data row2 col7" >0.2370</td>
#     </tr>
#     <tr>
#       <th id="T_fad54_level0_row3" class="row_heading level0 row3" >dummy</th>
#       <td id="T_fad54_row3_col0" class="data row3 col0" >Dummy Regressor</td>
#       <td id="T_fad54_row3_col1" class="data row3 col1" >0.0018</td>
#       <td id="T_fad54_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_fad54_row3_col3" class="data row3 col3" >0.0034</td>
#       <td id="T_fad54_row3_col4" class="data row3 col4" >-0.0131</td>
#       <td id="T_fad54_row3_col5" class="data row3 col5" >0.0034</td>
#       <td id="T_fad54_row3_col6" class="data row3 col6" >28.9565</td>
#       <td id="T_fad54_row3_col7" class="data row3 col7" >0.2230</td>
#     </tr>
#     <tr>
#       <th id="T_fad54_level0_row4" class="row_heading level0 row4" >en</th>
#       <td id="T_fad54_row4_col0" class="data row4 col0" >Elastic Net</td>
#       <td id="T_fad54_row4_col1" class="data row4 col1" >0.0018</td>
#       <td id="T_fad54_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_fad54_row4_col3" class="data row4 col3" >0.0034</td>
#       <td id="T_fad54_row4_col4" class="data row4 col4" >-0.0131</td>
#       <td id="T_fad54_row4_col5" class="data row4 col5" >0.0034</td>
#       <td id="T_fad54_row4_col6" class="data row4 col6" >28.9565</td>
#       <td id="T_fad54_row4_col7" class="data row4 col7" >0.2390</td>
#     </tr>
#     <tr>
#       <th id="T_fad54_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_fad54_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_fad54_row5_col1" class="data row5 col1" >0.0018</td>
#       <td id="T_fad54_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_fad54_row5_col3" class="data row5 col3" >0.0034</td>
#       <td id="T_fad54_row5_col4" class="data row5 col4" >-0.0131</td>
#       <td id="T_fad54_row5_col5" class="data row5 col5" >0.0034</td>
#       <td id="T_fad
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_1e964_row10_col0, #T_1e964_row10_col1, #T_1e964_row10_col2, #T_1e964_row10_col3, #T_1e964_row10_col4, #T_1e964_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1e964" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e964_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1e964_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1e964_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1e964_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1e964_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1e964_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e964_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e964_row0_col0" class="data row0 col0" >0.0015</td>
#       <td id="T_1e964_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_1e964_row0_col2" class="data row0 col2" >0.0022</td>
#       <td id="T_1e964_row0_col3" class="data row0 col3" >-0.0833</td>
#       <td id="T_1e964_row0_col4" class="data row0 col4" >0.0022</td>
#       <td id="T_1e964_row0_col5" class="data row0 col5" >2.0354</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e964_row1_col0" class="data row1 col0" >0.0013</td>
#       <td id="T_1e964_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_1e964_row1_col2" class="data row1 col2" >0.0018</td>
#       <td id="T_1e964_row1_col3" class="data row1 col3" >-0.0511</td>
#       <td id="T_1e964_row1_col4" class="data row1 col4" >0.0018</td>
#       <td id="T_1e964_row1_col5" class="data row1 col5" >7.2144</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e964_row2_col0" class="data row2 col0" >0.0016</td>
#       <td id="T_1e964_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_1e964_row2_col2" class="data row2 col2" >0.0030</td>
#       <td id="T_1e964_row2_col3" class="data row2 col3" >0.1098</td>
#       <td id="T_1e964_row2_col4" class="data row2 col4" >0.0030</td>
#       <td id="T_1e964_row2_col5" class="data row2 col5" >1.4060</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e964_row3_col0" class="data row3 col0" >0.0022</td>
#       <td id="T_1e964_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_1e964_row3_col2" class="data row3 col2" >0.0042</td>
#       <td id="T_1e964_row3_col3" class="data row3 col3" >0.0255</td>
#       <td id="T_1e964_row3_col4" class="data row3 col4" >0.0042</td>
#       <td id="T_1e964_row3_col5" class="data row3 col5" >2.8557</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e964_row4_col0" class="data row4 col0" >0.0023</td>
#       <td id="T_1e964_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_1e964_row4_col2" class="data row4 col2" >0.0048</td>
#       <td id="T_1e964_row4_col3" class="data row4 col3" >0.0361</td>
#       <td id="T_1e964_row4_col4" class="data row4 col4" >0.0047</td>
#       <td id="T_1e964_row4_col5" class="data row4 col5" >103.7998</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1e964_row5_col0" class="data row5 col0" >0.0014</td>
#       <td id="T_1e964_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_1e964_row5_col2" class="data row5 col2" >0.0027</td>
#       <td id="T_1e964_row5_col3" class="data row5 col3" >-0.0671</td>
#       <td id="T_1e964_row5_col4" class="data row5 col4" >0.0027</td>
#       <td id="T_1e964_row5_col5" class="data row5 col5" >2.3207</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1e964_row6_col0" class="data row6 col0" >0.0019</td>
#       <td id="T_1e964_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_1e964_row6_col2" class="data row6 col2" >0.0039</td>
#       <td id="T_1e964_row6_col3" class="data row6 col3" >0.1235</td>
#       <td id="T_1e964_row6_col4" class="data row6 col4" >0.0038</td>
#       <td id="T_1e964_row6_col5" class="data row6 col5" >1.6007</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1e964_row7_col0" class="data row7 col0" >0.0019</td>
#       <td id="T_1e964_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_1e964_row7_col2" class="data row7 col2" >0.0040</td>
#       <td id="T_1e964_row7_col3" class="data row7 col3" >0.0878</td>
#       <td id="T_1e964_row7_col4" class="data row7 col4" >0.0039</td>
#       <td id="T_1e964_row7_col5" class="data row7 col5" >91.6180</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1e964_row8_col0" class="data row8 col0" >0.0017</td>
#       <td id="T_1e964_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_1e964_row8_col2" class="data row8 col2" >0.0032</td>
#       <td id="T_1e964_row8_col3" class="data row8 col3" >0.0541</td>
#       <td id="T_1e964_row8_col4" class="data row8 col4" >0.0032</td>
#       <td id="T_1e964_row8_col5" class="data row8 col5" >2.3616</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1e964_row9_col0" class="data row9 col0" >0.0017</td>
#       <td id="T_1e964_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_1e964_row9_col2" class="data row9 col2" >0.0035</td>
#       <td id="T_1e964_row9_col3" class="data row9 col3" >0.0035</td>
#       <td id="T_1e964_row9_col4" class="data row9 col4" >0.0034</td>
#       <td id="T_1e964_row9_col5" class="data row9 col5" >85.1905</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_1e964_row10_col0" class="data row10 col0" >0.0018</td>
#       <td id="T_1e964_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_1e964_row10_col2" class="data row10 col2" >0.0033</td>
#       <td id="T_1e964_row10_col3" class="data row10 col3" >0.0239</td>
#       <td id="T_1e964_row10_col4" class="data row10 col4" >0.0033</td>
#       <td id="T_1e964_row10_col5" class="data row10 col5" >30.0403</td>
#     </tr>
#     <tr>
#       <th id="T_1e964_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_1e964_row11_col0" class="data row11 col0" >0.0003</td>
#       <td id="T_1e964_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_1e964_row11_col2" class="data row11 col2" >0.0009</td>
#       <td id="T_1e964_row11_col3" class="data row11 col3" >0.0695</td>
#       <td id="T_1e964_row11_col4" class="data row11 col4" >0.0009</td>
#       <td id="T_1e964_row11_col5" class="data row11 col5" >41.8107</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
